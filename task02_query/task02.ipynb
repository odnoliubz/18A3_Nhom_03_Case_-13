# %% [markdown]
# NHIỆM VỤ 2: TRUY VẤN VÀ THỐNG KÊ MÔ TẢ

# %%
import pandas as pd
df_patient = pd.read_csv("../data_clean/patient_info_clean.csv")
df_reaction = pd.read_csv("../data_clean/reaction_log_clean.csv")
df_vaccine = pd.read_csv("../data_clean/vaccination_record_clean.csv")

# %%
print(df_patient['age_group'].value_counts())
# Out:
# age_group
# 18-49    12
# 6-17     11
# 50+      10
# 0-5       7
# Name: count, dtype: int64

# %%
print(df_vaccine[df_vaccine['dose_number']>=2])
# Out:
#    patient_id vaccine_type  dose_number vaccination_date
# 1       BN520      covid19          3.0       2024-03-07
# 2       BN529        covid          3.0       2024-01-05
# 3       BN500      covid19          2.0       2024-04-15
# 6       BN528          mmr          2.0       2024-01-06
# 8       BN525          mmr          3.0       2024-05-25
# 9       BN510        covid          2.0       2024-05-24
# 10      BN538        covid          2.0       2024-01-17
# 11      BN504          mmr          3.0       2024-05-25
# 12      BN533      covid19          3.0       2024-02-19
# 15      BN503        covid          3.0       2024-04-20
# 21      BN503        covid          3.0       2024-05-13
# 22      BN504        covid          2.0       2024-04-22
# 24      BN502        d.p.t          3.0       2024-01-17
# 26      BN501        d.p.t          2.0       2024-03-25
# 28      BN538          dpt          3.0       2024-04-04
# 34      BN537        covid          3.0       2024-01-12
# 35      BN516      covid19          2.0       2024-03-27
# 36      BN523        covid          3.0       2024-02-13
# 37      BN508        covid          2.0       2024-02-19
# 38      BN523          dpt          2.0       2024-04-19
# 39      BN517        covid          2.0       2024-05-10
# 41      BN520      covid19          3.0       2024-05-14
# 42      BN527        d.p.t          2.0       2024-02-10
# 44      BN505          dpt          2.0       2024-05-11
# 48      BN513        d.p.t          2.0       2024-05-12
# 49      BN505          dpt          2.0       2024-04-19
# 51      BN501          dpt          2.0       2024-05-27
# 53      BN537          mmr          2.0       2024-01-09
# 54      BN509          dpt          2.0       2024-05-26
# 57      BN530          mmr          2.0       2024-05-27
