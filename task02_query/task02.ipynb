# %% [markdown]
# NHIỆM VỤ 2: TRUY VẤN VÀ THỐNG KÊ MÔ TẢ

# %%
import pandas as pd
df_patient = pd.read_csv("../data_raw/patient_info.csv")
df_vaccine = pd.read_csv("../data_raw/vaccination_record.csv")
df_reaction = pd.read_csv("../data_raw/reaction_log.csv")

# %%
dem_tuoi=(df_patient.groupby('age_group').size().reset_index(name='so_benh_nhan'))
print(dem_tuoi)
# Out:
#   age_group  so_benh_nhan
# 0   50plus              6
# 1       0-5             2
# 2       0_5             5
# 3     18-49             6
# 4     18_49             6
# 5       50+             4
# 6      6-17             7
# 7     6_17              4
